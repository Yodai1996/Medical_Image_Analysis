# %%
from perlin_numpy import (
    generate_fractal_noise_2d, generate_fractal_noise_3d,
    generate_perlin_noise_2d, generate_perlin_noise_3d
)

# %%
import matplotlib.pyplot as plt
import numpy as np
from perlin_numpy import (
    generate_perlin_noise_2d, generate_fractal_noise_2d
)

# %%
np.random.seed(0)
noise = generate_perlin_noise_2d((256, 256), (8, 8))
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()

plt.show()

# %%
np.random.seed(0)
noise = generate_perlin_noise_2d((32, 32), (8, 8))
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()

plt.show()

# %%
np.random.seed(0)
noise = generate_fractal_noise_2d((64, 64), (2, 2), 4)
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()

plt.show()

# %%
max(noise[27])
# Out:
# 0.9144295098305416

# %%
normalized_noize = (noise+1)/2  #0~1に正規化
ratio = 1-normalized_noize

# %%
plt.imshow(ratio, cmap='gray', interpolation='lanczos')
plt.colorbar()

plt.show()

# %%
min(normalized_noize[27])
# Out:
# 0.38676663946034373

# %%
max(ratio[27])
# Out:
# 0.6132333605396563

# %%
np.random.seed(0)
noise = generate_fractal_noise_2d((256, 256), (16, 16), 3, persistence=1, lacunarity=2)
plt.figure()
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()
plt.show()

# %%
np.random.seed(0)
noise = generate_fractal_noise_2d((256, 256), (16, 16), 3, persistence=0.2, lacunarity=2)
plt.figure()
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()
plt.show()

# %%
np.random.seed(0)
noise = generate_fractal_noise_2d((384, 384), (16, 16), 2, lacunarity=3)
plt.figure()
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()
plt.show()

# %%
np.random.seed(0)
noise = generate_fractal_noise_2d((256, 256), (8, 8), 5)
plt.figure()
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()
plt.show()

# %%
np.random.seed(0)
noise = generate_fractal_noise_2d((256, 256), (8, 8), 6)
plt.figure()
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()
plt.show()

# %%
np.random.seed(0)
noise = generate_fractal_noise_2d((256, 256), (4, 4), 6)
plt.figure()
plt.imshow(noise, cmap='gray', interpolation='lanczos')
plt.colorbar()
plt.show()
